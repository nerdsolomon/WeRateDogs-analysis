# %% [markdown]
# ### Reporting : act report
#
# The visualization below shows the tweet id on the x-axis which is labelled "Tweet IDs" the favorite count on the y-axis which is labelled "Favorite Counts" and a scale of 20,000 with a graph title that writes "The Most Favourited Tweets".
#
# The visualization shows the plot of the top three most favourited tweets, which was saved in a variable "most_favorited" after the Dataframe have been sorted in a descending order.
#
# From the visualization, we deduced that the tweet with Tweet id : 822872901745569793 and with the text;
# "Here's a super supportive puppo participating in the Toronto  #WomensMarch today. 13/10 https://t.co/nTz3FtorBc"
# is the most favourited tweet with favourite count of 132,810 and with a retweet count of 48,265.
#
# Which is followed by the tweet with Tweet ID : 744234799360020481 as the second most favourited tweet with a favorite count of 	131,075 and retweet count of 79,515.
#
# And the third most favourited tweet is the tweet with Tweet ID: 879415818425184262 with a favorite count of 107,956 and retweet count of 45,849.
#
# One of The likelihood why it is the most favourited tweet could be because of the inclusion of the hashtag #WomensMarch which extended it's audience to Twitter users outside the WeRateDogs profile.
#
# Also, another reason why it is the most favourited tweet could as well be because of it's high number of retweet count, which is 48265. So users who retweet this particular tweet could have their own followers view and favorite the post.

# %% [markdown]
# ![image.png](attachment:image.png)
